# %%
import time
from numpy import pi, cos, sin, linspace, roll, zeros_like
from bokeh.plotting import *
from bokeh.objects import GlyphRenderer

# %%
N = 50 + 1
r_base = 8
theta = linspace(0, 2*pi, N)
r_x = linspace(0, 6*pi, N-1)
rmin = r_base - cos(r_x) - 1
rmax = r_base + sin(r_x) + 1
colors = ["FFFFCC", "#C7E9B4", "#7FCDBB", "#41B6C4", "#2C7FB8", "#253494", "#2C7FB8", "#41B6C4", "#7FCDBB", "#C7E9B4"] * 5
cx = cy = zeros_like(rmin)

# %% [markdown]
# *To run these examples you must execute the command `python bokeh-server` in the top-level Bokeh source directory first.*

# %%
output_notebook(url="default")
# Out:
# Using saved session configuration for http://localhost:5006/
# To override, pass 'load_from_config=False' to Session
# /Volumes/Scratch/jcottam/Projects/Bokeh/bokeh/bokeh/session.py:356: UserWarning: You need to start the bokeh-server to see this example.
#   warnings.warn("You need to start the bokeh-server to see this example.")
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-a540ff299f38> in <module>()
# ----> 1 output_notebook(url="default")
#
# /Volumes/Scratch/jcottam/Projects/Bokeh/bokeh/bokeh/plotting.py in output_notebook(url, docname, session, name, force)
#     159         if docname is None:
#     160             docname = "IPython Session at %s" % time.ctime()
# --> 161         output_server(docname, url=url, session=session, name=name)
#     162     else:
#     163         from . import load_notebook
#
# /Volumes/Scratch/jcottam/Projects/Bokeh/bokeh/bokeh/plotting.py in output_server(docname, session, url, name)
#     151             _default_session = Session(name=name, root_url=url)
#     152         session = _default_session
# --> 153     session.use_doc(docname)
#     154     session.load_document(curdoc())
#     155
#
# /Volumes/Scratch/jcottam/Projects/Bokeh/bokeh/bokeh/session.pyc in use_doc(self, name, docid)
#     483             self.docid = docid
#     484         else:
# --> 485             self.docid = self.find_doc(name)
#     486         self.apikey = self.get_api_key(self.docid)
#     487
#
# /Volumes/Scratch/jcottam/Projects/Bokeh/bokeh/bokeh/session.pyc in find_doc(self, name)
#     446         """
#     447
# --> 448         docs = self.userinfo.get('docs')
#     449
#     450         matching = [x for x in docs if x.get('title') == name]
#
# /Volumes/Scratch/jcottam/Projects/Bokeh/bokeh/bokeh/session.pyc in userinfo(self)
#     401         if not hasattr(self, "_userinfo"):
#     402             url = urljoin(self.root_url, 'bokeh/userinfo/')
# --> 403             self._userinfo = self.get_json(url)
#     404         return self._userinfo
#     405
#
# /Volumes/Scratch/jcottam/Projects/Bokeh/bokeh/bokeh/session.pyc in get_json(self, url, headers, **kwargs)
#     379
#     380         """
# --> 381         return self.execute_json('get', url, headers=headers, **kwargs)
#     382
#     383     def post_json(self, url, headers=None, **kwargs):
#
# /Volumes/Scratch/jcottam/Projects/Bokeh/bokeh/bokeh/session.pyc in execute_json(self, method, url, headers, **kwargs)
#     355         except requests.exceptions.ConnectionError as e:
#     356             warnings.warn("You need to start the bokeh-server to see this example.")
# --> 357             raise e
#     358
#     359         if resp.status_code == 409:
#
# ConnectionError: ('Connection aborted.', error(61, 'Connection refused'))

# %%
figure(x_range=[-11, 11], y_range=[-11, 11], tools="pan,wheel_zoom,box_zoom,reset,previewsave")

# %%
annular_wedge(
    cx, cy, rmin, rmax, theta[:-1], theta[1:],
    inner_radius_units="data",
    outer_radius_units="data",
    fill_color = colors,
    line_color="black",
)

# %%
renderer = [r for r in curplot().renderers if isinstance(r, GlyphRenderer)][0]
ds = renderer.data_source
show()
while True:
    rmin = ds.data["inner_radius"]
    rmin = roll(rmin, 1)
    ds.data["inner_radius"] = rmin
    
    rmax = ds.data["outer_radius"]
    rmax = roll(rmax, -1)
    ds.data["outer_radius"] = rmax
    
    cursession().store_objects(ds)
    time.sleep(.10)
